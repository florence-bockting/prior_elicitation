# %%
import tensorflow_probability as tfp
import tensorflow as tf
import pandas as pd

tfd = tfp.distributions 

from elicit.core.run import prior_elicitation
from elicit.user.generative_models import ToyModel
from elicit.core.write_results import create_output_summary

# %% [markdown]
# ### The model
# The statistical model of the toy example is an intercept-only normal model with location $\mu$ and random noise $\sigma$. The location parameter $\mu$ is a function of the intercept $\beta_0$.
# $$
# \begin{align*}
#     (\beta_0,\sigma) &\sim p_\lambda(\cdot)\quad \quad &\text{Joint prior}\\
#     \mu &= \textbf{1}_N\beta_0 \quad \quad &\text{with obs}=1,\ldots, N\\
#     height_i &\sim \text{Normal}(\mu, \sigma) \quad \quad &\text{Likelihood}
# \end{align*}
# $$
# Our goal is to learn $p_\lambda(\cdot)$ where $\lambda$ are neural network weights used in the normalizing flows (NFs).
#
# Note: In the following we assume independence between the model parameters.

# %%
# implementation of the generative model
??ToyModel
# Out:
# Init signature: ToyModel()
# Docstring:      <no docstring>
# Source:
# class ToyModel:
#     def __call__(self, ground_truth, prior_samples, N):
#         # number of observations (intercept-only)
#         X = tf.ones((1,N))
#         # linear predictor (= mu)
#         epred = tf.expand_dims(prior_samples[:,:,0],-1) @ X
#         # data-generating model
#         likelihood = tfd.Normal(loc=epred,
#                                 scale=tf.expand_dims(prior_samples[:,:,1],-1))
#         # prior predictive distribution (=height)
#         ypred = likelihood.sample()
#
#         return dict(likelihood = likelihood,
#                     ypred = ypred,
#                     epred = epred,
#                     prior_samples = prior_samples
#                     )
# File:           c:\users\bockting\documents\github\prior_elicitation\elicit\user\generative_models.py
# Type:           type
# Subclasses:

# %% [markdown]
# ## Expert information
# **Example elicitation approach:**
#
# The expert is asked w.r.t.
# + their *median* ($Q_{50}$; value for which there is a 50/50 chance of being more or less)
# + the lower and upper quartiles ($Q_{25}$ and $Q_{75}$ respectively; the expert should judge it to be equally likely for $y$ to be below $Q_{25}$ or between $Q_{25}$ and $Q_{50}$, and they should also judge it equally likely that $y$ would be between $Q_{50}$ and $Q_{75}$ or above $Q_{75}$.)
# + the lower and upper boundary ($Q_{5}$ and $Q_{95}$ respectively; equivalent to min and max but more stable)
# + a coherence check: $Q_{5} < Q_{25} < Q_{50} < Q_{75} < Q_{95}$ (ranking should not be violated)

# %%
expert_info = pd.read_pickle("../../../elicit/simulations/parametric_prior_examples/expert_data/toy-example/elicited_statistics.pkl")

expert_data = pd.DataFrame(
    tf.round(expert_info["quantiles_ypred"]), 
    columns=[fr"$Q_{{{i}}}$" for i in [5,25,50,75,95]], 
    index = ["true"]
)

expert_data
# Out:
#       $Q_{5}$  $Q_{25}$  $Q_{50}$  $Q_{75}$  $Q_{95}$
# true    154.0     166.0     170.0     174.0     186.0

# %%
prior_elicitation(
    model_parameters=dict(
        mu=dict(param_scaling=1.),
        sigma=dict(param_scaling=1.),
        independence = True
        ),
    normalizing_flow = True,
    expert_data=dict(
        data=expert_info,
        from_ground_truth = False
        ),
    generative_model=dict(
        model=ToyModel,
        additional_model_args={
            "N": 200
            }
        ),
    target_quantities=dict(
        ypred=dict(
            elicitation_method="quantiles",
            quantiles_specs=(5, 25, 50, 75, 95),
            loss_components = "all"
            )
        ),
    optimization_settings=dict(
        optimizer_specs={
            "learning_rate": 0.001,
            "clipnorm": 1.0
            }
        ),
    training_settings=dict(
        method="deep_prior",
        sim_id="toy_example",
        seed=0,
        view_ep=1,
        epochs=200
    )
    )
# Out:
# epoch_time: 1.294 sec
# Epoch: 0, loss: 163.29585, lr: 0.001000
# epoch_time: 1.122 sec
# Epoch: 1, loss: 163.29054, lr: 0.001000
# Estimated time until completion: 00:04:17
# epoch_time: 1.030 sec
# Epoch: 2, loss: 163.24580, lr: 0.001000
# Estimated time until completion: 00:03:59
# epoch_time: 1.075 sec
# Epoch: 3, loss: 163.22318, lr: 0.001000
# Estimated time until completion: 00:03:46
# epoch_time: 1.029 sec
# Epoch: 4, loss: 163.17245, lr: 0.001000
# Estimated time until completion: 00:03:41
# epoch_time: 1.103 sec
# Epoch: 5, loss: 163.13808, lr: 0.001000
# Estimated time until completion: 00:03:36
# epoch_time: 1.024 sec
# Epoch: 6, loss: 163.06824, lr: 0.001000
# Estimated time until completion: 00:03:35
# epoch_time: 1.021 sec
# Epoch: 7, loss: 162.99365, lr: 0.001000
# Estimated time until completion: 00:03:31
# epoch_time: 1.014 sec
# Epoch: 8, loss: 162.92329, lr: 0.001000
# Estimated time until completion: 00:03:28
# epoch_time: 1.072 sec
# Epoch: 9, loss: 162.82672, lr: 0.001000
# Estimated time until completion: 00:03:26
# epoch_time: 1.039 sec
# Epoch: 10, loss: 162.72675, lr: 0.001000
# Estimated time until completion: 00:03:24
# epoch_time: 1.028 sec
# Epoch: 11, loss: 162.63019, lr: 0.001000
# Estimated time until completion: 00:03:23
# epoch_time: 1.146 sec
# Epoch: 12, loss: 162.46306, lr: 0.001000
# Estimated time until completion: 00:03:21
# epoch_time: 1.120 sec
# Epoch: 13, loss: 162.29121, lr: 0.001000
# Estimated time until completion: 00:03:21
# epoch_time: 1.041 sec
# Epoch: 14, loss: 162.06639, lr: 0.001000
# Estimated time until completion: 00:03:20
# epoch_time: 1.152 sec
# Epoch: 15, loss: 161.79991, lr: 0.001000
# Estimated time until completion: 00:03:19
# epoch_time: 1.116 sec
# Epoch: 16, loss: 161.37460, lr: 0.001000
# Estimated time until completion: 00:03:19
# epoch_time: 1.163 sec
# Epoch: 17, loss: 160.86174, lr: 0.001000
# Estimated time until completion: 00:03:18
# epoch_time: 1.061 sec
# Epoch: 18, loss: 160.08131, lr: 0.001000
# Estimated time until completion: 00:03:18
# epoch_time: 1.042 sec
# Epoch: 19, loss: 159.18134, lr: 0.001000
# Estimated time until completion: 00:03:16
# epoch_time: 1.045 sec
# Epoch: 20, loss: 157.38051, lr: 0.001000
# Estimated time until completion: 00:03:15
# Epoch: 120, loss: 1.37768, lr: 0.001000
# Estimated time until completion: 00:01:27
# epoch_time: 1.025 sec
# Epoch: 121, loss: 2.07197, lr: 0.001000
# Estimated time until completion: 00:01:26
# epoch_time: 1.019 sec
# Epoch: 122, loss: 1.34054, lr: 0.001000
# Estimated time until completion: 00:01:24
# epoch_time: 1.000 sec
# Epoch: 123, loss: 2.13799, lr: 0.001000
# Estimated time until completion: 00:01:23
# epoch_time: 0.989 sec
# Epoch: 124, loss: 1.37670, lr: 0.001000
# Estimated time until completion: 00:01:22
# epoch_time: 1.074 sec
# Epoch: 125, loss: 2.05275, lr: 0.001000
# Estimated time until completion: 00:01:21
# epoch_time: 1.072 sec
# Epoch: 126, loss: 1.29868, lr: 0.001000
# Estimated time until completion: 00:01:20
# epoch_time: 1.054 sec
# Epoch: 127, loss: 2.03786, lr: 0.001000
# Estimated time until completion: 00:01:19
# epoch_time: 1.034 sec
# Epoch: 128, loss: 1.27095, lr: 0.001000
# Estimated time until completion: 00:01:18
# epoch_time: 1.224 sec
# Epoch: 129, loss: 2.04727, lr: 0.001000
# Estimated time until completion: 00:01:17
# epoch_time: 1.038 sec
# Epoch: 130, loss: 1.24492, lr: 0.001000
# Estimated time until completion: 00:01:16
# epoch_time: 1.044 sec
# Epoch: 131, loss: 2.03659, lr: 0.001000
# Estimated time until completion: 00:01:14
# epoch_time: 1.057 sec
# Epoch: 132, loss: 1.24009, lr: 0.001000
# Estimated time until completion: 00:01:13
# epoch_time: 1.142 sec
# Epoch: 133, loss: 2.09208, lr: 0.001000
# Estimated time until completion: 00:01:12
# epoch_time: 1.063 sec
# Epoch: 134, loss: 1.25057, lr: 0.001000
# Estimated time until completion: 00:01:11
# epoch_time: 1.086 sec
# Epoch: 135, loss: 2.06869, lr: 0.001000
# Estimated time until completion: 00:01:10
# epoch_time: 1.051 sec
# Epoch: 136, loss: 1.19072, lr: 0.001000
# Estimated time until completion: 00:01:09
# epoch_time: 1.027 sec
# Epoch: 137, loss: 2.04561, lr: 0.001000
# Estimated time until completion: 00:01:08
# epoch_time: 1.028 sec
# Epoch: 138, loss: 1.19785, lr: 0.001000
# Estimated time until completion: 00:01:07
# epoch_time: 0.994 sec
# Epoch: 139, loss: 2.05420, lr: 0.001000
# Estimated time until completion: 00:01:06
# epoch_time: 1.037 sec
# Epoch: 140, loss: 1.24325, lr: 0.001000
# Estimated time until completion: 00:01:05
# epoch_time: 1.041 sec
# Epoch: 141, loss: 2.01288, lr: 0.001000
# Estimated time until completion: 00:01:03
# epoch_time: 1.121 sec
# Epoch: 142, loss: 1.22549, lr: 0.001000
# Estimated time until completion: 00:01:02
# epoch_time: 1.138 sec
# Epoch: 143, loss: 2.00813, lr: 0.001000
# Estimated time until completion: 00:01:01
# epoch_time: 1.189 sec
# Epoch: 144, loss: 1.22151, lr: 0.001000
# Estimated time until completion: 00:01:00
# epoch_time: 1.101 sec
# Epoch: 145, loss: 1.97148, lr: 0.001000
# Estimated time until completion: 00:00:59
# epoch_time: 1.039 sec
# Epoch: 146, loss: 1.23709, lr: 0.001000
# Estimated time until completion: 00:00:58
# epoch_time: 1.180 sec
# Epoch: 147, loss: 1.97996, lr: 0.001000
# Estimated time until completion: 00:00:57
# epoch_time: 1.070 sec
# Epoch: 148, loss: 1.22433, lr: 0.001000
# Estimated time until completion: 00:00:56
# epoch_time: 1.069 sec
# Epoch: 149, loss: 1.99048, lr: 0.001000
# Estimated time until completion: 00:00:55
# epoch_time: 1.007 sec
# Epoch: 150, loss: 1.23019, lr: 0.001000
# Estimated time until completion: 00:00:54
# epoch_time: 1.087 sec
# Epoch: 151, loss: 1.97720, lr: 0.001000
# Estimated time until completion: 00:00:53
# epoch_time: 1.069 sec
# Epoch: 152, loss: 1.18468, lr: 0.001000
# Estimated time until completion: 00:00:52
# epoch_time: 1.008 sec
# Epoch: 153, loss: 1.94266, lr: 0.001000
# Estimated time until completion: 00:00:50
# epoch_time: 1.023 sec
# Epoch: 154, loss: 1.19981, lr: 0.001000
# Estimated time until completion: 00:00:49
# epoch_time: 1.055 sec
# Epoch: 155, loss: 1.91933, lr: 0.001000
# Estimated time until completion: 00:00:48
# epoch_time: 1.101 sec
# Epoch: 156, loss: 1.21037, lr: 0.001000
# Estimated time until completion: 00:00:47
# epoch_time: 1.120 sec
# Epoch: 157, loss: 1.94785, lr: 0.001000
# Estimated time until completion: 00:00:46
# epoch_time: 1.133 sec
# Epoch: 158, loss: 1.23669, lr: 0.001000
# Estimated time until completion: 00:00:45
# epoch_time: 1.091 sec
# Epoch: 159, loss: 1.93018, lr: 0.001000
# Estimated time until completion: 00:00:44
# epoch_time: 1.070 sec
# Epoch: 160, loss: 1.22513, lr: 0.001000
# Estimated time until completion: 00:00:43
# epoch_time: 1.026 sec
# Epoch: 161, loss: 1.87892, lr: 0.001000
# Estimated time until completion: 00:00:42
# epoch_time: 1.097 sec
# Epoch: 162, loss: 1.20997, lr: 0.001000
# Estimated time until completion: 00:00:41
# epoch_time: 1.024 sec
# Epoch: 163, loss: 1.90939, lr: 0.001000
# Estimated time until completion: 00:00:40
# epoch_time: 0.976 sec
# Epoch: 164, loss: 1.19386, lr: 0.001000
# Estimated time until completion: 00:00:39
# epoch_time: 0.953 sec
# Epoch: 165, loss: 1.89762, lr: 0.001000
# Estimated time until completion: 00:00:37
# epoch_time: 1.001 sec
# Epoch: 166, loss: 1.19231, lr: 0.001000
# Estimated time until completion: 00:00:36
# epoch_time: 1.179 sec
# Epoch: 167, loss: 1.95061, lr: 0.001000
# Estimated time until completion: 00:00:35
# epoch_time: 1.022 sec
# Epoch: 168, loss: 1.22230, lr: 0.001000
# Estimated time until completion: 00:00:34
# epoch_time: 1.021 sec
# Epoch: 169, loss: 1.85132, lr: 0.001000
# Estimated time until completion: 00:00:33
# epoch_time: 1.024 sec
# Epoch: 170, loss: 1.19269, lr: 0.001000
# Estimated time until completion: 00:00:32
# epoch_time: 1.024 sec
# Epoch: 171, loss: 1.89930, lr: 0.001000
# Estimated time until completion: 00:00:31
# epoch_time: 1.149 sec
# Epoch: 172, loss: 1.18880, lr: 0.001000
# Estimated time until completion: 00:00:30
# epoch_time: 1.120 sec
# Epoch: 173, loss: 1.90812, lr: 0.001000
# Estimated time until completion: 00:00:29
# epoch_time: 1.039 sec
# Epoch: 174, loss: 1.22355, lr: 0.001000
# Estimated time until completion: 00:00:28
# epoch_time: 1.046 sec
# Epoch: 175, loss: 1.90622, lr: 0.001000
# Estimated time until completion: 00:00:27
# epoch_time: 1.114 sec
# Epoch: 176, loss: 1.20457, lr: 0.001000
# Estimated time until completion: 00:00:25
# epoch_time: 1.024 sec
# Epoch: 177, loss: 1.91003, lr: 0.001000
# Estimated time until completion: 00:00:24
# epoch_time: 1.014 sec
# Epoch: 178, loss: 1.20993, lr: 0.001000
# Estimated time until completion: 00:00:23
# epoch_time: 1.055 sec
# Epoch: 179, loss: 1.88657, lr: 0.001000
# Estimated time until completion: 00:00:22
# epoch_time: 1.028 sec
# Epoch: 180, loss: 1.20840, lr: 0.001000
# Estimated time until completion: 00:00:21
# epoch_time: 1.067 sec
# Epoch: 181, loss: 1.90805, lr: 0.001000
# Estimated time until completion: 00:00:20
# epoch_time: 1.069 sec
# Epoch: 182, loss: 1.23086, lr: 0.001000
# Estimated time until completion: 00:00:19
# epoch_time: 1.017 sec
# Epoch: 183, loss: 1.86973, lr: 0.001000
# Estimated time until completion: 00:00:18
# epoch_time: 1.060 sec
# Epoch: 184, loss: 1.20568, lr: 0.001000
# Estimated time until completion: 00:00:17
# epoch_time: 1.101 sec
# Epoch: 185, loss: 1.89889, lr: 0.001000
# Estimated time until completion: 00:00:16
# epoch_time: 1.072 sec
# Epoch: 186, loss: 1.19475, lr: 0.001000
# Estimated time until completion: 00:00:15
# epoch_time: 1.068 sec
# Epoch: 187, loss: 1.91271, lr: 0.001000
# Estimated time until completion: 00:00:14
# epoch_time: 1.083 sec
# Epoch: 188, loss: 1.19059, lr: 0.001000
# Estimated time until completion: 00:00:12
# epoch_time: 0.991 sec
# Epoch: 189, loss: 1.91167, lr: 0.001000
# Estimated time until completion: 00:00:11
# epoch_time: 1.009 sec
# Epoch: 190, loss: 1.19994, lr: 0.001000
# Estimated time until completion: 00:00:10
# epoch_time: 1.022 sec
# Epoch: 191, loss: 1.85391, lr: 0.001000
# Estimated time until completion: 00:00:09
# epoch_time: 1.040 sec
# Epoch: 192, loss: 1.17001, lr: 0.001000
# Estimated time until completion: 00:00:08
# epoch_time: 1.070 sec
# Epoch: 193, loss: 1.82904, lr: 0.001000
# Estimated time until completion: 00:00:07
# epoch_time: 1.008 sec
# Epoch: 194, loss: 1.22074, lr: 0.001000
# Estimated time until completion: 00:00:06
# epoch_time: 1.031 sec
# Epoch: 195, loss: 1.85884, lr: 0.001000
# Estimated time until completion: 00:00:05
# epoch_time: 1.023 sec
# Epoch: 196, loss: 1.22207, lr: 0.001000
# Estimated time until completion: 00:00:04
# epoch_time: 1.038 sec
# Epoch: 197, loss: 1.85908, lr: 0.001000
# Estimated time until completion: 00:00:03
# epoch_time: 1.150 sec
# Epoch: 198, loss: 1.19931, lr: 0.001000
# Estimated time until completion: 00:00:02
# epoch_time: 1.114 sec
# Epoch: 199, loss: 1.89054, lr: 0.001000
# Estimated time until completion: 00:00:01
# Done :)

# %% [markdown]
# ## Results
#
# ### Loss function and convergence

# %%
from elicit.plotting import func
path = "./elicit/results/deep_prior/toy_example_0"

import matplotlib.pyplot as plt
import seaborn as sns

#func.plot_loss(path)
prior = tf.reshape(pd.read_pickle(path+"/prior_samples.pkl"), (128*200,2))

g = sns.PairGrid(pd.DataFrame(prior))
g.map(sns.scatterplot)

# %%
hyp = pd.read_pickle(path+"/final_results.pkl")["hyperparameter"]
hyp_val = tf.stack([hyp[k] for k in hyp], -1)
hyp_key = [k for k in list(hyp.keys())]

_, axs = plt.subplots(1,hyp_val.shape[-1], constrained_layout=True, figsize=(6,3),
                     sharex=True)
[axs[i].plot(hyp_val[:,i]) for i in range(hyp_val.shape[-1])]
[axs[i].set_title(hyp_key[i]) for i in range(hyp_val.shape[-1])]
[axs[i].set_xlabel("epochs") for i in range(hyp_val.shape[-1])]
plt.show()

# %% [markdown]
# ### Elicited statistics

# %%
model_data = pd.DataFrame(
    tf.round(tf.reduce_mean(pd.read_pickle(path+"/elicited_statistics.pkl")["quantiles_ypred"],0)[None,:]),
    columns=[fr"$Q_{{{i}}}$" for i in [5,25,50,75,95]], 
    index=["model"])

pd.concat([expert_data, model_data])
# Out:
#        $Q_{5}$  $Q_{25}$  $Q_{50}$  $Q_{75}$  $Q_{95}$
# true     154.0     166.0     170.0     174.0     186.0
# model    153.0     166.0     170.0     174.0     186.0

# %% [markdown]
# ### Prior distributions

# %%
import matplotlib.pyplot as plt

hyp=pd.read_pickle(path+"/final_results.pkl")["hyperparameter"]
learned_hyp=tf.reduce_mean(tf.stack([hyp[k][-30:] for k in hyp],-1), 0)
gd = pd.read_pickle(path+"/global_dict.pkl")

xrge = tf.range(0.,50., 0.01)
xrge2 = tf.range(140.,200., 0.01)
sigma = gd["model_parameters"]["sigma"]["family"](learned_hyp[2]).prob(xrge)
mu = gd["model_parameters"]["mu"]["family"](learned_hyp[1], tf.exp(learned_hyp[0])).prob(xrge2)

_, axs = plt.subplots(1,2, constrained_layout=True, figsize=(6,3))
axs[0].plot(xrge, sigma)
axs[0].set_title(rf"$\sigma \sim Normal_+({learned_hyp[2]:.2f})$")
axs[1].plot(xrge2, mu)
axs[1].set_title(rf"$\mu \sim Normal({learned_hyp[1]:.2f}, {tf.exp(learned_hyp[0]):.2f})$")
plt.show()
